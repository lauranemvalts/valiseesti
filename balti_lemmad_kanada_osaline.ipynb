# %%
import sys
# !{sys.executable} -m spacy download en
import re, numpy as np, pandas as pd
from pprint import pprint

# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import lemmatize, simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

# %matplotlib inline
warnings.filterwarnings("ignore",category=DeprecationWarning)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import et_dep_ud_xlmroberta
import spacy

import pyLDAvis
import pyLDAvis.gensim

# %%
file = open("balti_concs_kanada.txt", encoding="UTF-8")

# %%
data = file.read()

# %%
data_into_list = data.split("\n")
print(data_into_list)
file.close()
# Out:
# ['m kontakt ja eriti südamik ja tihe olema see kolm balti rahvas vahel  riiginõukogu liige min  J Müller', 'as ja Eesti koguni kahjulik  mis tahtma sakslane balti riik maa-ala suurendamine saavutama  pidama meel', 'enemaa nõrgestama  Venemaa külg maa äralõikamine balti  GeneralhezirkGeneralhezirki  suurendamine', 'iis äratama see ajakiri number suur tähelepanu ka balti põgenik keskel  Eesti pagnlasajakirjandus olema ', 'kelaager  kus pögenikuteekond algul asuma ainult balti rahvas  Omalajal tõusma seal eestlane arv ligi 2', 'a tähendamatähendanud  et kõik põgenik  rahvus balti meri kuni must meri  olema läänemaailm põgenema', ' see sobivus või ka erakondlik side järg jne  ka balti riik paneel koosseis olema kuuldus järgi huvitama', 'dudLiit port vägivaldselt okupeerimaokupeeritud balti riik olukord  Ester Rõhl sina suur imensiivsus s', ' ka I R-cxMsiF leiduma veel ringkond  kes pidama balti riik anastamine enamlane 3   i kommunistlik par', 'ilisem suu  rema selts üritus võima märkima kolm balti rahvas  poolt ühiselt korraldamakorraldatud peo', 'ahelt pildistamapildistatud foto Stalin ausammas balti jaam ees  mis mina meelespüsiv pilt Toompea nõlv', 'mestik rida linn  mis asuma vallutamavallutatud balti riik piir ääres  jiagu Pihkva  Vitebsk  Gomel ', 'päev võtma  Järg 4 lkj see olema Korea Truman  balti riik saama kindlasti vaba kolmapäev viibima läti ', 'lia  Holland ja Luxemburg  sõdur  suur front  balti meri kuni Alpid  saksa armee moodustama ühe kolm', 'edulane ümmarkusi 1000 hing  olema seega tugevam balti rahvas grupp  tema olema Miami koguni 5 organisa', 'Miami Eesti-Amee-rika Kultuurlklubi organiseerima balti rahvas õhtu  nüüd korraldama Miami leedulane oma', 'õtma osa 2000 inimene  rende hulgas ka esindaja balti riik ja teine raudeesriidetagune rahvus hulgast ', 'ine poolt kõik läinudminema aasta ilmumailmunud balti riik oma  olema moodustamamoodustatud or-j ORTO', 'New York teatama suurem eesti organisatsioon  et balti riigriigiriigide vabaduskomitee   Baltic Stat', 'sindaja suurem meeleavalduslik aktus korraldamine balti riik küsimus tutvustamine New York  kõnesolev ür', 'nevEsinevaEsinevad ligi 60 kunstnik 20 rahvus  balti  poola  ukraina  austria  ungari  taani  no', 'rik seltsk  ruum mag  mail Jürma loeng teema  balti naine nõukogu töö USA  kõneleja tervitama tema ', ' Jürma j praegu kuuluma tema otsene tõoicl andmed balti naine töö i ülesanne uurimistöö  mis puutuma - s', 'e ja leedulane  olema ühendriik andmaantud kolm balti rahvas sama tegutsemine võimalus teine Euroopa ra', 'ne USA ekspresident HooverHooveri Eesti ja teine balti riik vaenlane olema kärme olemaolnud lääs levima', 's Smetonas poliitiline seisukoht kokkuvõte  kolm balti riik president olema Läti riigipea Karl Ulmanis e', 'klikult kokku saama  tenit  kes olema tõeliselt balti meri punalaevastik komandant adjutant  tee mina ', 'Ameerika ühendriik Joh  Käiv  kes rõhutama  et balti riik saatus olenema suurriik välispoliitiline suh', 'us kaudu  O K Armstrong olema tundmatuntud ka balti rahvas sõber ja tema äratama kogu maailm ulatusli', 'all  igasugune materjal  mis siia veerema ka balti riik  Leedu endine sadamalinn Klaipeda  nüüdne ', 'Vene ise iseseisev demokraatlik vabariik  pärast balti riige iseseisvus taastamine liitma Ingerimaa Eest', 'laskma venelane ilma pikemata maha ühe USA lennuk balti meri ja teine Jaapan meri kohal  Vene spioon USA', 'oolt ohvitser andmaantud seletus järgi varitsema baltisakslane soodnesoodus silmapilk  et see natuken', 'lus jätmajätnud  ise kätte kiskuma  see tahtma baltisakslane manööverdama prof  J UluotsUluotsa dr ', 'eemaldamine järele Eesti omavalitsus eesots olema baltisakslane siis riigisakslasteie selge tegemateinud', 't ei leiduma  mis järele see olema läinudminema baltisakslane kätte  niisugune olema dr  MäeMägi inf', 'aastamataastatud ja taastama kogu aeg endine Venebalti laevatehas  Eesti aeg sinna asutamaasutatud ja ', 'lik  see olema ühine rindrinne loomine Eesti ja balti riik päevakord välja langemalang ...

# %%
data2 = np.array(data_into_list)

# %%
dataset = [d.split() for d in data2]

# %%
# Creating the term dictionary of our courpus, where every unique term is assigned an index. 
dictionary = corpora.Dictionary(dataset)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in dataset]

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=3, id2word = dictionary, passes=50)

# %%
print(ldamodel.print_topics(num_topics=3, num_words=3))
# Out:
# [(0, '0.060*"balti" + 0.020*"ja" + 0.009*"olema"'), (1, '0.066*"balti" + 0.044*"riik" + 0.022*"ja"'), (2, '0.057*"balti" + 0.035*"olema" + 0.030*"ja"')]
